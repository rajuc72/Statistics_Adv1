# %% [markdown]
# ##Statistics Advance Part 1
# ####1.What is a random variable in probability theory?
#
# Ans: A random variable is a variable whose possible values are outcomes of a random experiment.
#
# ####2. What are the types of random variables?
#
# Ans: We have two types of random variables.
# Discrete Random Variables: Take on countable values (e.g., number of heads in coin tosses, no.of cars , no.of mobile phones).
# Continuous Random Variables: Take on an infinite number of values within a range (e.g., height, weight).
#
# ####3. What is the difference between discrete and continuous distributions?
#
# Ans: Discrete Distributions: Deal with countable outcomes.
# Continuous Distributions: Deal with outcomes that can take any value within a range.
#
# ####4.What are probability distribution functions (PDF)?
#
# Ans: Probability Density Function (PDF) is used for continuous random variables. It provides the density of probabilities rather than the exact probabilities because the probability of a continuous variable taking any exact value is essentially zero.
# Example: Imagine you have a uniformly distributed continuous random variable that represents the height of people in a certain town, ranging from 150 cm to 200 cm. The PDF in this case might look something like a rectangle where each height between 150 cm and 200 cm is equally likely.
# If you wanted to find the probability that a person's height is between 160 cm and 170 cm, you would calculate the area under the PDF curve from 160 to 170.
#
# ####5.How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# Ans: Cumulative Distribution Function (CDF) represents the cumulative probability that a random variable will take a value less than or equal to a specific value. It’s the integral of the PDF for continuous variables or the sum of the probabilities for discrete variables.
# Example: Using the same height example, the CDF would start at 0 at 150 cm, and increase linearly to 1 at 200 cm. If you want to know the probability that a person's height is less than or equal to 170 cm, you would look at the CDF value at 170 cm.
# If the CDF at 170 cm is 0.4, it means there is a 40% chance that a randomly selected person’s height is less than or equal to 170 cm.
# PDF: Represents probability of a specific value.
# CDF: Represents cumulative probability up to a certain value.
#
# ####6. What is a discrete uniform distribution?
#
# Ans: Uniform Distribution is nothing but every outcome of a finite number of outcomes has an equal probability.
#
# ####7.What are the key properties of a Bernoulli distribution?
#
# Ans: A Bernoulli Distribution describes a random variable that has exactly two possible outcomes: success (1) and failure (0). It's defined by a single parameter 𝑝, which is the probability of success.
# Key Properties of Bernoulli Distribution : Mean=p, Variance =1-p.
# Ex: Tossing a coin
#
# ####8. What is the binomial distribution, and how is it used in probability?
# Ans: A Binomial Distribution extends the Bernoulli distribution to multiple trials. It represents the number of successes in 𝑛 independent Bernoulli trials with the same probability of success 𝑝.
# Ex: Tossing a Coin 100 times. The probability of getting exactly 57 heads successes in 100 trials.
#
# ####9. What is the Poisson distribution and where is it applied?
#
# Ans: Poisson Distribution is nothing but finding the number of events occurring within a fixed interval of time or space. Applied in scenarios like counting the number of emails received per hour, no.of busses/trains in an hour.
#
# ####10. What is a continuous uniform distribution?
#
# Ans: Every value in an interval has an equal probability of occurring.
#
# ####11.What are the characteristics of a normal distribution?
#
# Ans: A Normal Distribution is Symmetrical, forms a bell-shaped curve. Mean, median, and mode are equal.
#
# ####12.What is the standard normal distribution, and why is it important?
#
# Ans: A normal distribution with a mean/Z score of 0 and a standard deviation of 1. It's important for standardizing data.
#
# ####13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# Ans: The Central Limit Theorem (CLT) is a fundamental principle in probability and statistics. It states that, given a sufficiently large sample size, the distribution of the sample means will approximate a normal distribution (bell curve), regardless of the shape of the population distribution.
# Key Points:
# Sample Size: The larger the sample size, the closer the sample mean distribution will be to a normal distribution.
# Population Distribution: The original population distribution can be skewed, uniform, or any other.
# Mean and Standard Deviation: The mean of the sample means will equal the population mean. The standard deviation of the sample means (known as the standard error) will be the population standard deviation divided by the square root of the sample size.
# Example: Imagine you're measuring the heights of people in a town. If you take multiple random samples of a large enough size (e.g., 30 or more), the means of these samples will form a normal distribution, even if the original population distribution of heights isn't perfectly normal.
#
# ####14.How does the Central Limit Theorem relate to the normal distribution?
#
# Ans: The CLT is crucial because it explains why the normal distribution (or bell curve) appears so frequently in statistics. Due to the CLT, we can make inferences about the population even when we don't know the exact distribution of the population.
#
# Key Relationship:
# Estimation: The normal distribution allows us to make probability statements about the sample means. For example, we can use Z-scores to find probabilities and confidence intervals.
# Practical Application: Because of the CLT, many statistical methods and hypothesis tests assume a normal distribution. This makes the analysis robust and widely applicable.
#
# ####15.What is the application of Z statistics in hypothesis testing?
#
# Ans: Z score used to determine if there is a significant difference between sample and population means.
#
# ####16.How do you calculate a Z-score, and what does it represent?
#
# Ans: Z score= (Individual value(X)-Average of total no.of observation) /Standard Deviation.
#
# ####17. What are point estimates and interval estimates in statistics?
#
# Ans: Point Estimate: A point estimate is a single value given as the estimate of a parameter of a population. It’s a specific numerical value.
# Example: Estimating the average height of students in a class by measuring the height of a randomly selected student. If the measured height is 160 cm, this is your point estimate for the average height.
# Interval Estimate: An interval estimate gives a range within which the parameter is expected to lie, providing more information about the variability.
# Example: Instead of just saying the average height is 160 cm, you might say the average height is between 155 cm and 165 cm with 95% confidence. This range is called a confidence interval.
#
# ####18. What is the significance of confidence intervals in statistical analysis?
#
# Ans: Confidence Intervals: A confidence interval is a range of values, derived from the sample data, that is likely to contain the value of an unknown population parameter.
# Example: Suppose you survey a group of people to estimate the average number of hours they sleep. If you find the average to be 7 hours with a 95% confidence interval of [6.5, 7.5], you are 95% confident that the true average sleep time for the population is between 6.5 and 7.5 hours.
# Significance: Confidence intervals provide a measure of uncertainty. They tell you how confident you can be in your estimate and give a range where the true parameter is likely to lie.
#
#
# ####19. What is the relationship between a Z-score and a confidence interval?
#
# Ans: Z-scores help determine the margin of error for confidence intervals.
#
# ####20. How are Z-scores used to compare different distributions?
#
# Ans: Z scores facilitate comparison of data from different distributions by standardizing them.
#
# ####21. What are the assumptions for applying the Central Limit Theorem?
#
# Ans: Primarily we have the following assumption for applying the CLT:
# Random sampling.
# Independent samples.
# Sufficiently large sample size.
#
# ####22. What is the concept of expected value in a probability distribution?
#
# Ans: Expected value is nothing but the mean value of a random variable in the long run.
#
# ####23.How does a probability distribution relate to the expected outcome of a random variable?
#
# Ans: Expected Value: The expected value of a random variable is the long-run average value it takes on after many repetitions of the same experiment. It is a measure of the central tendency of the distribution and is often denoted by 𝐸(X).
# If you roll a fair six-sided die, the possible values are 1, 2, 3, 4, 5, and 6, each with a probability of 1/6. The expected value of the roll is: 3.5
# The expected value provides a single summary measure of the distribution that tells you what outcome you can "expect" on average if you repeat the experiment many times. It's a fundamental concept that helps in making predictions and understanding the behaviour of random variables.

# %% [markdown]
# ####1.Write a Python program to generate a random variable and display its value.

# %%
import numpy as np
import pandas as pd
random_variable = np.random.random()
print(random_variable)
# Out:
# 0.7648204730355673

# %% [markdown]
# ####2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

# %%
import numpy as np
import matplotlib.pyplot as plt
low = 1
high = 6
size = 10000  # Number of samples
# Generate random samples
samples = np.random.randint(low, high+1, size=size)
# Calculate the PMF
values, counts = np.unique(samples, return_counts=True)
pmf = counts / size
# Plot the PMF
plt.plot(values,pmf,color='red')
plt.bar(values, pmf, color='blue', alpha=0.7)
#plt.hist2d(values, pmf, bins=30, cmap='Blues')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability Mass Function (PMF) of a Discrete Uniform Distribution')
plt.grid(False)
plt.legend(loc='upper right')
plt.show()
# Out:
# <ipython-input-2-7679b2f82ee0>:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper right')

# %% [markdown]
# ####3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
import warnings
warnings.filterwarnings('ignore')
def bernoulli_pdf(x, p):

    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1")

    return p if x == 1 else 1 - p

p = float(input("Enter the probability of success (p) between 0 and 1: "))
x = int(input("Enter the value (0 for failure or 1 for success): "))
print(bernoulli_pdf(x,p))
# Out:
# Enter the probability of success (p) between 0 and 1: 0.4
# Enter the value (0 for failure or 1 for success): 1
# 0.4

# %% [markdown]
# ####4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
n = 10  # number of trials
p = 0.5  # probability of success
size = 1000  # number of simulations
# Simulate the binomial distribution
data = np.random.binomial(n, p, size)
# Plot the histogram
plt.hist(data, bins=range(n+2), edgecolor='red', alpha=0.7)
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.xticks(range(n+1))  # Set x-ticks for all possible outcomes from 0 to 10
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ####5.Create a Poisson distribution and visualize it using Python.

# %%
lambda_value = 5  # Average rate (λ)
size = 1000  # Number of samples
# Generate Poisson distribution data
data = np.random.poisson(lambda_value, size)
# Plot the histogram
plt.hist(data, bins=range(0, max(data)+1), edgecolor='black', alpha=0.6)
plt.title(f'Poisson Distribution (λ={lambda_value})')
plt.xlabel('Number of Events')
plt.ylabel('Frequency')
plt.xticks(range(0, max(data)+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ####6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

# %%
low = 1  # Lower bound of the distribution (inclusive)
high = 6  # Upper bound of the distribution (inclusive)
size = 1000  # Number of samples
# Generate the discrete uniform distribution data
data = np.random.randint(low, high + 1, size)
# Calculate the CDF
values, counts = np.unique(data, return_counts=True)
cdf = np.cumsum(counts) / size
# Plot the CDF as a step plot
plt.step(values, cdf, where='post', label='CDF')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title(f'Cumulative Distribution Function (CDF) of Discrete Uniform Distribution\nRange = [{low}, {high}]')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ####7.Generate a continuous uniform distribution using NumPy and visualize it.

# %%
low = 0
high = 10
size = 1000
data = np.random.uniform(low, high, size)
plt.hist(data, bins=30, density=True, edgecolor='black', alpha=0.7)
x = np.linspace(low, high, 1000)
pdf = np.ones_like(x) / (high - low)
plt.plot(x, pdf, label='PDF')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Continuous Uniform Distribution (Range = [{low}, {high}])')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ####8.Simulate data from a normal distribution and plot its histogram.

# %%
mean_math = 75
std_dev_math = 10
mean_science = 80
std_dev_science = 15
sample_size = 1000
math_scores = np.random.normal(mean_math, std_dev_math, sample_size)
science_scores = np.random.normal(mean_science, std_dev_science, sample_size)
# Create histograms of the data
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(math_scores, bins=30, edgecolor='black', alpha=0.7)
plt.title('Math Scores - Normal Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(science_scores, bins=30, edgecolor='black', alpha=0.7)
plt.title('Science Scores - Normal Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####9.Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
def calculate_and_plot_z_scores(data):
    # Calculate the mean and standard deviation of the data
    mean = np.mean(data)
    std_dev = np.std(data)
    # Calculate the Z-scores
    z_scores = (data - mean) / std_dev
    # Plot the histogram of Z-scores
    plt.hist(z_scores, bins=30, edgecolor='black', alpha=0.7)
    plt.title('Histogram of Z-scores')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.show()
    return z_scores

data = np.random.normal(50, 10, 1000)  # Generating random data from a normal distribution
z_scores = calculate_and_plot_z_scores(data)

# %% [markdown]
# ####10.Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

# %%
# Parameters for the exponential distribution
lambda_param = 1.0  # Rate parameter
sample_size = 1000  # Large number of samples
num_experiments = 1000  # Number of experiments to demonstrate CLT
# Generate random data from the exponential distribution
data = np.random.exponential(scale=1/lambda_param, size=(num_experiments, sample_size))
# Calculate the sample means
sample_means = np.mean(data, axis=1)
# Plot the histogram of the sample means
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
plt.title('Histogram of Sample Means (Central Limit Theorem)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ####15.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
mean = 50
std_dev = 10
sample_size = 30  # Size of each sample
num_samples = 1000  # Number of samples
samples = np.random.normal(mean, std_dev, (num_samples, sample_size))
sample_means = np.mean(samples, axis=1)
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)
plt.title('Histogram of Sample Means (Central Limit Theorem)')
plt.xlabel('Sample Mean')
plt.ylabel('Frequency')
# Plot the theoretical normal distribution for comparison
mean_theoretical = mean
std_dev_theoretical = std_dev / np.sqrt(sample_size)
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, (1 / (std_dev_theoretical * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean_theoretical) / std_dev_theoretical)**2), color='red')
plt.show()

# %% [markdown]
# ####16.Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

# %%
def plot_standard_normal_distribution():
    x = np.linspace(-4, 4, 1000)
    mean = 0
    std_dev = 1
    pdf = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)
    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')
    plt.title('Standard Normal Distribution (Mean = 0, Std Dev = 1)')
    plt.xlabel('Values')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_standard_normal_distribution()

# %% [markdown]
# ####17.Generate random variables and calculate their corresponding probabilities using the binomial distribution

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5  # Probability of success on each trial
num_samples = 1000  # Number of samples to generate

# Generate random variables from the binomial distribution
random_variables = np.random.binomial(n, p, num_samples)

# Calculate the probability mass function (PMF) for each possible number of successes
k_values = np.arange(n + 1)
pmf_values = binom.pmf(k_values, n, p)

# Plot the histogram of the random variables
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(random_variables, bins=np.arange(n+2)-0.5, edgecolor='black', alpha=0.7)
plt.title('Histogram of Binomial Random Variables')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
# Plot the PMF using plt.plot
plt.subplot(1, 2, 2)
plt.plot(k_values, pmf_values, marker='o', linestyle='-', color='blue')
plt.title('Binomial Distribution PMF')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.tight_layout()
plt.show()
# Print the calculated probabilities
for k, pmf in zip(k_values, pmf_values):
    print(f"Probability of {k} successes: {pmf:.4f}")
# Out:
# Probability of 0 successes: 0.0010
# Probability of 1 successes: 0.0098
# Probability of 2 successes: 0.0439
# Probability of 3 successes: 0.1172
# Probability of 4 successes: 0.2051
# Probability of 5 successes: 0.2461
# Probability of 6 successes: 0.2051
# Probability of 7 successes: 0.1172
# Probability of 8 successes: 0.0439
# Probability of 9 successes: 0.0098
# Probability of 10 successes: 0.0010

# %% [markdown]
# ####18.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal Distribution

# %%
from scipy.stats import norm
def calculate_z_score(data_point, mean, std_dev):
    return (data_point - mean) / std_dev
def plot_standard_normal_distribution(z_score):
    x = np.linspace(-4, 4, 1000)
    # Calculate the standard normal distribution (mean=0, std=1)
    pdf = norm.pdf(x, 0, 1)
    # Plot the standard normal distribution
    plt.plot(x, pdf, color='blue', label='Standard Normal Distribution')
    # Plot the Z-score on the standard normal distribution
    plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score = {z_score:.2f}')
    plt.fill_between(x, 0, pdf, where=(x <= z_score), color='red', alpha=0.3)

    plt.title('Standard Normal Distribution with Z-score')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Sample data point, mean, and standard deviation
data_point = 75
mean = 60
std_dev = 10
# Calculate the Z-score
z_score = calculate_z_score(data_point, mean, std_dev)
print(f"Z-score for data point {data_point}: {z_score:.2f}")
# Plot the standard normal distribution and highlight the Z-score
plot_standard_normal_distribution(z_score)
# Out:
# Z-score for data point 75: 1.50

# %% [markdown]
# ####19.Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import scipy.stats as stats
# Sample data
sample_data = [52, 55, 53, 54, 56, 51, 54, 53, 52, 55]
sample_mean = np.mean(sample_data)
sample_size = len(sample_data)
# Population parameters
population_mean = 50
population_std_dev = 5
# Calculate the Z-score
z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))
print(f"Z-score: {z_score:.2f}")
# Determine the p-value for the Z-score
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))
print(f"P-value: {p_value:.4f}")
# Determine the critical value for a 5% significance level (two-tailed test)
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha / 2)
print(f"Critical Z-value: ±{z_critical:.2f}")
# Compare the Z-score with the critical value
if abs(z_score) > z_critical:
    print("Reject the null hypothesis (H0). The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis (H0). The sample mean is not significantly different from the population mean.")
# Out:
# Z-score: 2.21
# P-value: 0.0269
# Critical Z-value: ±1.96
# Reject the null hypothesis (H0). The sample mean is significantly different from the population mean.

# %% [markdown]
# ####20.Create a confidence interval for a dataset using Python and interpret the result.

# %%
sample_data = [52, 55, 53, 54, 56, 51, 54, 53, 52, 55]
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)
sample_size = len(sample_data)
# Define the confidence level
confidence_level = 0.95
alpha = 1 - confidence_level
# Calculate the critical Z-value (two-tailed)
z_critical = stats.norm.ppf(1 - alpha / 2)
# Calculate the standard error (SE)
standard_error = sample_std_dev / np.sqrt(sample_size)
# Calculate the margin of error (ME)
margin_of_error = z_critical * standard_error
# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
# Print the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Standard Deviation: {sample_std_dev:.2f}")
print(f"Sample Size: {sample_size}")
print(f"Critical Z-value: {z_critical:.2f}")
print(f"Standard Error: {standard_error:.2f}")
print(f"Margin of Error: {margin_of_error:.2f}")
print(f"95% Confidence Interval: {confidence_interval}")
# Interpret the result
print(f"We are {confidence_level * 100}% confident that the true population mean lies within the range {confidence_interval}.")
# Out:
# Sample Mean: 53.50
# Standard Deviation: 1.58
# Sample Size: 10
# Critical Z-value: 1.96
# Standard Error: 0.50
# Margin of Error: 0.98
# 95% Confidence Interval: (52.52001800772997, 54.47998199227003)
# We are 95.0% confident that the true population mean lies within the range (52.52001800772997, 54.47998199227003).

# %% [markdown]
# ####21.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

# %%
# Parameters for the normal distribution
mean = 50  # Population mean
std_dev = 10  # Population standard deviation
sample_size = 100  # Number of samples
# Generate random data from the normal distribution
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(mean, std_dev, sample_size)
# Calculate the sample mean and standard deviation
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)
# Define the confidence level
confidence_level = 0.95
alpha = 1 - confidence_level
# Calculate the critical Z-value (two-tailed)
z_critical = stats.norm.ppf(1 - alpha / 2)
# Calculate the standard error (SE)
standard_error = sample_std_dev / np.sqrt(sample_size)
# Calculate the margin of error (ME)
margin_of_error = z_critical * standard_error
# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
# Print the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Standard Deviation: {sample_std_dev:.2f}")
print(f"Sample Size: {sample_size}")
print(f"Critical Z-value: {z_critical:.2f}")
print(f"Standard Error: {standard_error:.2f}")
print(f"Margin of Error: {margin_of_error:.2f}")
print(f"95% Confidence Interval: {confidence_interval}")
# Interpret the result
print(f"We are {confidence_level * 100}% confident that the true population mean lies within the range {confidence_interval}.")
# Out:
# Sample Mean: 48.96
# Standard Deviation: 9.08
# Sample Size: 100
# Critical Z-value: 1.96
# Standard Error: 0.91
# Margin of Error: 1.78
# 95% Confidence Interval: (47.18155741526743, 50.74151223685072)
# We are 95.0% confident that the true population mean lies within the range (47.18155741526743, 50.74151223685072).

# %% [markdown]
# ####22.Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
# Parameters for the normal distribution
mean = 0  # Mean of the distribution
std_dev = 1  # Standard deviation of the distribution
# Define the range of x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
# Calculate the PDF values
pdf = norm.pdf(x, mean, std_dev)
# Plot the PDF
plt.figure(figsize=(10, 6))
plt.plot(x, pdf, label=f'Normal Distribution (mean={mean}, std_dev={std_dev})', color='blue')
plt.fill_between(x, pdf, alpha=0.2, color='blue')
plt.title('Probability Density Function of a Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ####23.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson
# Parameter for the Poisson distribution (λ)
lambda_param = 3  # Example: mean number of occurrences is 3
# Define the range of x values
x = np.arange(0, 15)  # From 0 to 14
# Calculate the CDF values
cdf_values = poisson.cdf(x, lambda_param)
# Plot the CDF
plt.figure(figsize=(10, 6))
plt.step(x, cdf_values, where='mid', label=f'Poisson CDF (λ={lambda_param})', color='blue')
plt.title('Cumulative Distribution Function of a Poisson Distribution')
plt.xlabel('Number of occurrences (x)')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Print the CDF values
for i, cdf in zip(x, cdf_values):
    print(f"CDF for x = {i}: {cdf:.4f}")
# Out:
# CDF for x = 0: 0.0498
# CDF for x = 1: 0.1991
# CDF for x = 2: 0.4232
# CDF for x = 3: 0.6472
# CDF for x = 4: 0.8153
# CDF for x = 5: 0.9161
# CDF for x = 6: 0.9665
# CDF for x = 7: 0.9881
# CDF for x = 8: 0.9962
# CDF for x = 9: 0.9989
# CDF for x = 10: 0.9997
# CDF for x = 11: 0.9999
# CDF for x = 12: 1.0000
# CDF for x = 13: 1.0000
# CDF for x = 14: 1.0000

# %% [markdown]
# ####24.Simulate a random variable using a continuous uniform distribution and calculate its expected value.

# %%
lower_bound = 0
upper_bound = 10
num_samples = 1000
# Generate random variables from the uniform distribution
np.random.seed(42)  # For reproducibility
random_variables = np.random.uniform(lower_bound, upper_bound, num_samples)
# Calculate the expected value (mean)
expected_value = np.mean(random_variables)
# Print the expected value
print(f"Expected Value (Mean) of the Uniform Distribution: {expected_value:.2f}")
# Visualize the uniform distribution
plt.figure(figsize=(10, 6))
plt.hist(random_variables, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram of Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Expected Value (Mean) of the Uniform Distribution: 4.90

# %% [markdown]
# ####25.Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
np.random.seed(42)  # For reproducibility
dataset1 = np.random.normal(loc=50, scale=5, size=1000)  # Mean=50, Std Dev=5
dataset2 = np.random.normal(loc=50, scale=15, size=1000)  # Mean=50, Std Dev=15
# Calculate the standard deviations
std_dev1 = np.std(dataset1, ddof=1)
std_dev2 = np.std(dataset2, ddof=1)
# Print the standard deviations
print(f"Standard Deviation of Dataset 1: {std_dev1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_dev2:.2f}")
# Visualize the datasets
plt.figure(figsize=(12, 6))
plt.hist(dataset1, bins=30, alpha=0.5, label=f'Dataset 1 (Std Dev={std_dev1:.2f})', color='blue')
plt.hist(dataset2, bins=30, alpha=0.5, label=f'Dataset 2 (Std Dev={std_dev2:.2f})', color='orange')
plt.title('Comparison of Standard Deviations for Two Datasets')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96

# %% [markdown]
# ####26.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

# %%
# Parameters for the normal distribution
mean = 50  # Mean of the distribution
std_dev = 10  # Standard deviation of the distribution
sample_size = 1000  # Number of samples
# Generate random data from the normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(mean, std_dev, sample_size)
# Calculate the range
data_range = np.max(data) - np.min(data)
# Calculate the interquartile range (IQR)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1
# Print the results
print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr:.2f}")
# Visualize the data distribution
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Range of the dataset: 70.94
# Interquartile Range (IQR) of the dataset: 12.96

# %% [markdown]
# ####27.Implement Z-score normalization on a dataset and visualize its transformation.

# %%
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)
# Calculate the mean and standard deviation of the original dataset
mean = np.mean(data)
std_dev = np.std(data)
# Apply Z-score normalization
normalized_data = (data - mean) / std_dev
# Calculate the mean and standard deviation of the normalized dataset
normalized_mean = np.mean(normalized_data)
normalized_std_dev = np.std(normalized_data)
# Print the means and standard deviations
print(f"Original Dataset Mean: {mean:.2f}, Standard Deviation: {std_dev:.2f}")
print(f"Normalized Dataset Mean: {normalized_mean:.2f}, Standard Deviation: {normalized_std_dev:.2f}")
# Visualize the original and normalized datasets
plt.figure(figsize=(12, 6))
# Histogram of the original dataset
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Original Dataset')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Histogram of the normalized dataset
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Normalized Dataset')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Original Dataset Mean: 50.19, Standard Deviation: 9.79
# Normalized Dataset Mean: -0.00, Standard Deviation: 1.00

# %% [markdown]
# ####28.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution

# %%
from scipy.stats import skew, kurtosis
def calculate_skewness_kurtosis(data):
    # Calculate skewness
    skewness = skew(data)
    # Calculate kurtosis
    kurt = kurtosis(data)
    return skewness, kurt
# Generate a sample dataset from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=50, scale=10, size=1000)
# Calculate skewness and kurtosis
skewness, kurt = calculate_skewness_kurtosis(data)
# Print the results
print(f"Skewness of the dataset: {skewness:.2f}")
print(f"Kurtosis of the dataset: {kurt:.2f}")
# Interpretation
if skewness > 0:
    skewness_description = "positively skewed"
elif skewness < 0:
    skewness_description = "negatively skewed"
else:
    skewness_description = "symmetrical"
if kurt > 0:
    kurtosis_description = "leptokurtic (fat tails)"
elif kurt < 0:
    kurtosis_description = "platykurtic (thin tails)"
else:
    kurtosis_description = "mesokurtic (normal tails)"

print(f"The dataset is {skewness_description}.")
print(f"The dataset is {kurtosis_description}.")
# Out:
# Skewness of the dataset: 0.12
# Kurtosis of the dataset: 0.07
# The dataset is positively skewed.
# The dataset is leptokurtic (fat tails).
